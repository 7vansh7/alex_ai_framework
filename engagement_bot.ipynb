# %%
import google.generativeai as genai
import PIL.Image as Image
import requests

# %%
calorie_or_nutritional_information = {'function_declarations': [
      {'name': 'calorie_or_nutritional_information',
       'description': 'returns the calorific breakdown and nutritional information data about a food item like calories,protein,carbohydrates',
       'parameters': {'type_': 'OBJECT',
       'properties': {
         'a': {'type_': 'STRING'}
       },
       'required': ['a']} }]}
genai.protos.Tool(calorie_or_nutritional_information)
# model._tools.to_proto()
# Out:
# function_declarations {
#   name: "calorie_or_nutritional_information"
#   description: "returns the calorific breakdown and nutritional information data about a food item like calories,protein,carbohydrates"
#   parameters {
#     type_: OBJECT
#     properties {
#       key: "a"
#       value {
#         type_: STRING
#       }
#     }
#     required: "a"
#   }
# }

# %%
safety_settings = [
  {
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_NONE"
  },
  {
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_NONE"
  },
  {
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_NONE"
  },
  {
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_NONE"
  }
]
def calorie_or_nutritional_information(food_name:str):
    url = "https://trackapi.nutritionix.com/v2/natural/nutrients"
    # url2 = "https://trackapi.nutritionix.com/v2/search/instant/?query=mcdonaldsalootikki"
    headers = {"Content-Type": "application/json",
              "x-app-id":"4031d7ed",
              "x-app-key":"77c515afe6b2c5fd3dfba64d0c005213"}
    body = {"query": food_name}
    response = requests.post(url,json=body, headers=headers)
    # response = requests.get(url2, headers=headers)
    return str(response.json())
instruction = '''You are a Virtual assitant responsible for customer engagement in a food delievery company called 
Zomato,Your name is Alex, you answer various questions related to food and calorific information'''

genai.configure(api_key='AIzaSyAxDlqSHz9f7MjpWngTe_hKiMBEbtowbMU')

model = genai.GenerativeModel('gemini-1.5-flash',safety_settings=safety_settings,
                              system_instruction=instruction,tools=[calorie_or_nutritional_information])
# model = genai.GenerativeModel('gemini-1.5-pro')
history = []

chat = model.start_chat(history=history,enable_automatic_function_calling=True)

# %%
image = Image.open('./IMG_2769.PNG')
prompt1 = 'can you tell me more about the dish, what is it made up of?'
prompt3 = 'how many calories are there in a average mcdonalds veg burger?' + 'this is the relevant data' + str(data)
res = chat.send_message(['what is a calorie'],stream=False)
print(res.text)
# for x in res:
#     print(res.text)
# Out:
# response:
# GenerateContentResponse(
#     done=True,
#     iterator=None,
#     result=protos.GenerateContentResponse({
#       "candidates": [
#         {
#           "content": {
#             "parts": [
#               {
#                 "text": "That's a great question! \ud83d\ude0a  A calorie is a unit of energy.  It's the amount of energy needed to raise the temperature of 1 gram of water by 1 degree Celsius. \n\nThink of it like this:  When you eat food, your body breaks it down and uses the calories in that food to fuel your activities, like walking, running, or even just breathing!  \n\nSo, the calories you consume from food are what give you the energy to do all the things you need to do throughout the day.  \n\nDoes that make sense? \n"
#               }
#             ],
#             "role": "model"
#           },
#           "finish_reason": "STOP",
#           "index": 0,
#           "safety_ratings": [
#             {
#               "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
#               "probability": "NEGLIGIBLE"
#             },
#             {
#               "category": "HARM_CATEGORY_HATE_SPEECH",
#               "probability": "NEGLIGIBLE"
#             },
#             {
#               "category": "HARM_CATEGORY_HARASSMENT",
#               "probability": "NEGLIGIBLE"
#             },
#             {
#               "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
#               "probability": "NEGLIGIBLE"
#             }
#           ],
#           "citation_metadata": {
#             "citation_sources": [
#               {
#                 "start_index": 31,
#                 "end_index": 153,
#                 "uri": "",
#                 "license_": ""
#               }
#             ]
#           }
#         }
#       ],
#       "usage_metadata": {
#         "prompt_token_count": 5583,
#         "candidates_token_count": 119,
#         "total_token_count": 5702
#       }
#     }),
# )

# %%
# nutrtionix website is a good source, it is a food calorie database
query = 'calories in malai chaap'
url = 'https://www.googleapis.com/customsearch/v1'
query = query
engine_id = '428d10eb5a7e14c98'
api_key = 'AIzaSyAKeHCDiIFgR_pHH6vIeweZ14DnGdDsm5Y'
params = {
    'q': query,
    'key': api_key,
    'cx': engine_id
}
links = []
# snippets = []
res = requests.get(url,params=params)
results = res.json()['items']
[links.append(x['link']) for x in re sults ]
data = requests.get(links[0])
print(data.text)
# Out:
# <!DOCTYPE html><html lang='en' dir='ltr' style='padding: 0; margin: 0;'><head prefix='og: http://ogp.me/ns#'><meta http-equiv='Content-Type' content='text/html; charset=utf-8' /><link as='script' rel='preload' href='https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-27-691154c7c2510bef.webpack' /><link as='script' rel='preload' href='https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-vendor-27-c663ad026f3abd51.webpack' /><link as='script' rel='preload' href='https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-27-dc20115054165b10.webpack' /><link as='script' rel='preload' href='https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-page-QuestionPageLoadable-27-b280b4639ecabc6d.webpack' /><link as='script' rel='preload' href='https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Ad-27-29b074ee8d7f250a.webpack' /><link as='script' rel='preload' href='https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-QuestionPage-27-71d06feadacc022b.webpack' /><link as='script' rel='preload' href='https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-LoggedOut-27-e763301fb87ccfe7.webpack' /><link as='style' rel='preload' href='https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-main.css-28-f4ef3e8b8aa95a7d.webpack' /><link rel='stylesheet' type='text/css' href='https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-main.css-28-f4ef3e8b8aa95a7d.webpack' id='ans-frontend-main-css' /><script type="text/javascript">function reportToAndroid(){if(0!==assetErrs.length){var e=window.QuoraAndroid;e&&e.reportBrowserAssetLoadErrors&&e.reportBrowserAssetLoadErrors(assetErrs)}}var assetErrs=[];document.addEventListener("DOMContentLoaded",function(e){setTimeout(function(){if(0!==assetErrs.length){var e="assets="+encodeURIComponent(JSON.stringify(assetErrs)),r=new XMLHttpRequest;r.open("POST","/ajax/log_browser_asset_load_error_3RD_PARTY_POST",!0),r.setRequestHeader("Content-Type","application/x-www-form-urlencoded; charset=UTF-8"),r.setRequestHeader("Accept","*/*"),r.send(e.replace(/%20/g,"+"))}},0),setTimeout(function(){reportToAndroid()},500)}),window.addAssetErr=function(e){e&&assetErrs.push(e)};
# </script><script type="text/javascript" id="entryjs_wrapper">
#         window.__entryChunkLoaded = false;
#         window.__onEntryLoaded = [];
#         window.executeAfterEntryjsLoaded = function (callback) {
#             if (window.__entryChunkLoaded) {
#                 callback();
#             } else {
#                 window.__onEntryLoaded.push(callback);
#             }
#         }
#     </script><script type="text/javascript">window.isReactPage = true;window.isReactLoaded = true;window.ansFrontendRelayWebpackManifest = {"common":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-27-dc20115054165b10.webpack","common-LoggedOut":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-LoggedOut-27-e763301fb87ccfe7.webpack","common-Mweb":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-Mweb-27-fe3608d1c8ab488e.webpack","common-NativeApp":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-NativeApp-27-be931d61c74f842c.webpack","common-secondary":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-secondary-27-79c0dd1e53487ed3.webpack","component-ActivationDeckInner":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-ActivationDeckInner-27-7e4f1d09e7f96f80.webpack","component-Ad":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Ad-27-29b074ee8d7f250a.webpack","component-AdCTABanner":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-AdCTABanner-27-e33a9ca3b3535e78.webpack","component-AdminTools-profile":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-AdminTools-profile-27-6b05d4b7b067d1e0.webpack","component-AnnouncementBundle":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-AnnouncementBundle-27-7f48680bada034bf.webpack","component-AnswerFooter":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-AnswerFooter-27-03f92bf1339723dc.webpack","component-AnswerPageFooter":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-AnswerPageFooter-27-b40974992985667b.webpack","component-CaptchaPopper":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-CaptchaPopper-27-033dabcf52446ce1.webpack","component-CollapseAnswerSection":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-CollapseAnswerSection-27-46def3e32d966bc2.webpack","component-CommentAd":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-CommentAd-27-225c247fde8fa068.webpack","component-Comments":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Comments-27-59e6d66a7ac74d27.webpack","component-FeedSwitcher":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-FeedSwitcher-27-a79c0c85ec925f8e.webpack","component-FirstFeedScrollPrompt":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-FirstFeedScrollPrompt-27-cecf99b296db8a6a.webpack","component-GenericRightRail-Ad":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-GenericRightRail-Ad-27-5a6c6a74d1df3e7a.webpack","component-Hovercards":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Hovercards-27-26226c53b9fb7b0e.webpack","component-ImageViewer":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-ImageViewer-27-1335409ca545ce29.webpack","component-LightweightSurvey":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-LightweightSurvey-27-de331435b6d9dbbf.webpack","component-LoggedOutFeed":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-LoggedOutFeed-27-f31f207a3c91f459.webpack","component-Login":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Login-27-63a980c7473a77e1.webpack","component-MobileLookup":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-MobileLookup-27-880714a548f55e2c.webpack","component-Modals-AdsConsumer":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Modals-AdsConsumer-27-a1d1f001e690a5b7.webpack","component-Modals-AdsManager":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Modals-AdsManager-27-505e615f6d6c675a.webpack","component-Modals-AskQuestion":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Modals-AskQuestion-27-2b7b1d096fb94604.webpack","component-Modals-Business":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Modals-Business-27-91b7edced30aacc2.webpack","component-Modals-EarningsPrograms":"https://qsbr.cf2.quoracdn.net/-4-ans_frontend-rel ...
# var includedChunks = window.ansFrontendRelayWebpackIncludedChunks;
# window.ansFrontendRelayWebpackIncludedChunks = (includedChunks || []).concat(["vendor","common","page-QuestionPageLoadable","component-Ad","component-QuestionPage","common-LoggedOut"]);</script><script type="text/javascript">window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.earlySettings = {"formkey": "d821ec6b624fadc15ae07d7400aa6d47", "errorSamplingRate": 1.0, "interfaceLanguageCode": "en", "isDevCode": false, "isMobileAppPrefetched": false, "topLevelNid": 0, "react_console_log_perf_info": false, "subdomainSuffix": "quora.com", "windowId": "react_iunqkinyxqlspoya", "rootClsKey": "QuestionPage", "rootQueryVariables": {"questionSlug": "How-many-calories-does-Malai-Chaap-have", "questionSlugEncoded": "How-many-calories-does-Malai-Chaap-have", "redirectedQid": 0, "topAid": null, "first": 50, "forceScoreVersion": null}, "rootProps": {}, "pageWrapperQueryVariables": {}, "inlineQueryHashes": {"c12792e9c0fa867fe5c0cb965bb2b50cc3b9a649bbff1c21888523da641fb3a7": true, "3eb65034a996ef24ddf80bf4198f7602c9182f50914149ca92fd912ee13d691b": true, "2c53c95b6864960e46e30505e303ddc4782353d243dc22a3de8388cc31980083": true}, "pageShellInfo": null, "shouldServerRender": false, "hasIndicator": true, "isServiceWorkerConstructed": false};</script><script type="text/javascript">function getLoggingUrl(){var e="/ajax/page_bounce_POST";return"quora.com"==window.ansFrontendGlobals.earlySettings.subdomainSuffix?"https://log.quora.com/ajax/page_bounce_POST":e}function logPageBounce(e){if(window.isReactPage&&!window.reportedPageLoadBounce&&!window.ansFrontendGlobals.earlySettings.isMobileAppPrefetched&&!window.ansFrontendGlobals.earlySettings.isPrefetchedPage){window.reportedPageLoadBounce=!0;var n=window.ansFrontendGlobals.earlySettings.windowId,o={url:window.location.href,windowId:n,wasViewed:window.wasViewed};if(window.performance&&window.performance.timing){var a=window.performance.timing.navigationStart;a&&(o.unloadTime=Date.now()-a,o.cause=e)}var i=getLoggingUrl(),t=window.ansFrontendGlobals.earlySettings.formkey,d=[{category:"unload_before_page_ready",data:o,time:1e3*Date.now()}];try{var r=new window.FormData;r.append("messages",JSON.stringify(d)),r.append("formkey",t),window.navigator.sendBeacon(i,r)}catch(w){var s=new XMLHttpRequest;s.open("POST",i,!0),s.setRequestHeader("Content-Type","application/x-www-form-urlencoded; charset=UTF-8"),
# s.setRequestHeader("Quora-Formkey",t);var g="messages="+encodeURIComponent(JSON.stringify(d));s.setRequestHeader("Accept","*/*"),s.send(g.replace(/%20/g,"+"))}}}window.wasViewed="visible"===document.visibilityState,window.addEventListener("beforeunload",function(e){logPageBounce("beforeunload")}),window.addEventListener("pagehide",function(e){logPageBounce("pagehide")}),window.addEventListener("visibilitychange",function(e){"hidden"===document.visibilityState?logPageBounce("visibilitychange_hidden"):window.wasViewed=!0});
# </script><script type='text/javascript' src='https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-27-691154c7c2510bef.webpack' async='1' onerror='addAssetErr(this.src)' id='entryjs'></script><script type='text/javascript' src='https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-vendor-27-c663ad026f3abd51.webpack' async='1' onerror='addAssetErr(this.src)'></script><script type='text/javascript' src='https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-27-dc20115054165b10.webpack' async='1' onerror='addAssetErr(this.src)'></script><script type='text/javascript' src='https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-page-QuestionPageLoadable-27-b280b4639ecabc6d.webpack' async='1' onerror='addAssetErr(this.src)'></script><script type='text/javascript' src='https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-Ad-27-29b074ee8d7f250a.webpack' async='1' onerror='addAssetErr(this.src)'></script><script type='text/javascript' src='https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-component-QuestionPage-27-71d06feadacc022b.webpack' async='1' onerror='addAssetErr(this.src)'></script><script type='text/javascript' src='https://qsbr.cf2.quoracdn.net/-4-ans_frontend-relay-common-LoggedOut-27-e763301fb87ccfe7.webpack' async='1' onerror='addAssetErr(this.src)'></script><script type="text/javascript">window.executeAfterEntryjsLoaded(() => window.runApp());</script>
#         <script type="application/ld+json">
#         {"@context": "http://schema.org", "@type": "QAPage", "mainEntity": {"@type": "Question", "about": [{"@type": "Thing", "image": "https://qph.cf2.quoracdn.net/main-thumb-t-1026-100-ohvgqriqzmtjrnillbxqoyfstjxhmlcu.jpeg", "name": "Food"}, {"@type": "Thing", "image": "https://qph.cf2.quoracdn.net/main-thumb-t-1244-100-gLAmRxlsuTTFexNRBRtEbZGCSRyemecm.jpeg", "name": "Nutrition"}, {"@type": "Thing", "image": "https://qph.cf2.quoracdn.net/main-thumb-t-1244-100-gLAmRxlsuTTFexNRBRtEbZGCSRyemecm.jpeg", "name": "Calories"}, {"@type": "Thing", "image": "https://qph.cf2.quoracdn.net/main-thumb-t-3239-100-RSQUsoM8bAghJkyg37zbbYgC991ZTXbv.jpeg", "name": "Fitness"}, {"@type": "Thing", "image": "https://qph.cf2.quoracdn.net/main-thumb-t-59364-100-8V6GWQKOAlz75HLJs3C1ZXVW5OIk0uWx.jpeg", "name": "Burning Calories"}], "answerCount": 8, "author": {"@type": "Person", "agentInteractionStatistic": {"@type": "InteractionCounter", "interactionType": "http://schema.org/ReplyAction", "userInteractionCount": 90}, "image": "https://qph.cf2.quoracdn.net/main-thumb-167902201-100-gipsfdefknyrrrashxazqwlnetbgogpp.jpeg", "interactionStatistic": {"@type": "InteractionCounter", "interactionType": "http://schema.org/FollowAction", "userInteractionCount": 661}, "name": "Soniya Chandlani", "url": "https://www.quora.com/profile/Soniya-Chandlani"}, "dateCreated": "2021-07-31T11:31:15.703170+00:00", "dateModified": "2023-08-04T13:46:06.479431+00:00", "name": "How many calories does Malai Chaap have?", "suggestedAnswer": [{"@type": "Answer", "author": {"@type": "Person", "name": "ChatGPT"}, "dateCreated": "2023-02-28T07:11:57.500119+00:00", "text": "Malai Chaap is a popular Indian dish made with soybean chaap cooked in a creamy and spicy gravy. The number of calories in Malai Chaap can vary depending on the recipe and serving size. However, on average, a 100-gram serving of Malai Chaap contains approximately 220-250 calories.", "url": "https://www.quora.com/How-many-calories-does-Malai-Chaap-have?top_ans=1477743646021007"}, {"@type": "Answer", "author": {"@type": "Person", "agentInteractionStatistic": {"@type": "InteractionCounter", "interactionType": "http://schema.org/ReplyAction", "userInteractionCount": 134}, "description": "lives in Visakhapatnam, Andhra Pradesh, India (2000-present)", "homeLocation": {"@type": "Place", "name": "Visakhapatnam, Andhra Pradesh, India"}, "image": "https://qph.cf2.quoracdn.net/main-thumb-2269960624-100-wgelwqwjyogfsadbzbqogsxatqdoeavo.jpeg", "interactionStatistic": {"@type": "InteractionCounter", "interactionType": "http://schema.org/FollowAction", "userInteractionCount": 27}, "name": "Divha", "url": "https://www.quora.com/profile/Divha"}, "dateCreated": "2023-08-04T13:46:06.479431+00:00", "image": [{"@type": "ImageObject", "contentUrl": "https://qph.cf2.quoracdn.net/main-qimg-b3a64aa372252a08decf89461bdc982d"}], "parentItem": {"@type": "Comment", "text": "How many calories does Malai Chaap have?", "url": "https://changeyourhub.quora.com/How-many-calories-does-Malai-Chaap-have"}, "text": "Malai cheep have a Amino acids that are present in chaap can reduce and repair the immune system. The digestive ability of malai chaap could improve functions of cells that repair the immunity of the body.\n\n", "upvoteCount": 0, "url": "https://www.quora.com/How-many-calories-does-Malai-Chaap-have?top_ans=1477743685112924"}, {"@type": "Answer", "author": {"@type": "Person", "agentInteractionStatistic": {"@type": "InteractionCounter", "interactionType": "http://schema.org/ReplyAction", "userInteractionCount": 127}, "description": "Self Employed (2016-present)", "hasOccupation": {"@type": "Role", "roleName": "Self Employed", "startDate": "2016"}, "image": "https://qph.cf2.quoracdn.net/main-thumb-1390377796-100-sdohgrzmornnznrgnrrdgwqhbjndpbyj.jpeg", "interactionStatistic": {"@type": "InteractionCounter", "interactionType": "http://schema.org/FollowAction", "userInteractionCount": 14}, "name": "Sports", "url": "https://www.quora.com/profile/Spor ...
#         </script>
#     <title>How many calories does Malai Chaap have? - Quora</title><link rel='icon' href='https://qsf.cf2.quoracdn.net/-4-images.favicon-new.ico-26-07ecf7cd341b6919.ico' /><meta name="robots" content="noarchive" /><meta property='fb:app_id' content='136609459636' /><meta property='og:title' content='How many calories does Malai Chaap have?' /><meta property='og:type' content='article' /><meta property='og:site_name' content='Quora' /><meta property='og:image' content='https://qph.cf2.quoracdn.net/main-custom-t-1026-600x315-tuweelugqmmnjoppjqnscdiehwmhpjry.jpeg' /><meta property='og:url' content='https://www.quora.com/How-many-calories-does-Malai-Chaap-have' /><meta property='og:description' content='Answer (1 of 8): 1 chap has 150cals (raw)
#
# Malai and veggies adds up to 150 cals more
#
# And half plate consists of 2 chaps I guess so it would be 450–500cals' /><meta name='twitter:card' content='summary_large_image' /><meta name='twitter:site' content='@Quora' /><meta name='twitter:url' content='https://www.quora.com/How-many-calories-does-Malai-Chaap-have' /><meta name='twitter:title' content='How many calories does Malai Chaap have?' /><meta name='twitter:description' content='Answer (1 of 8): 1 chap has 150cals (raw)
#
# Malai and veggies adds up to 150 cals more
#
# And half plate consists of 2 chaps I guess so it would be 450–500cals' /><meta name='twitter:image' content='https://qph.cf2.quoracdn.net/main-custom-t-1026-600x315-tuweelugqmmnjoppjqnscdiehwmhpjry.jpeg' /><meta name='description' content='1 chap has 150cals (raw) Malai and veggies adds up to 150 cals more And half plate consists of 2 chaps I guess so it would be 450–500cals' /><link rel='canonical' href='https://www.quora.com/How-many-calories-does-Malai-Chaap-have' /><meta property='fb:pages' content='255232486973' /><meta name='twitter:widgets:theme' content='light' /></head><body class='q-platform--desktop' style='margin: 0;padding: 0;'><div id='staticError' style='display: none;'><div style='height: 100vh; display: flex; font-size: 15px;background-color: #fff; color: #282829;flex-direction: column; align-items: center; justify-content: center;font-family: -apple-system,system-ui,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen-Sans,Ubuntu,Cantarell,"Helvetica Neue",sans-serif;'><svg width="24px" height="24px" viewBox="0 0 24 24">
#     <g
#       id="error"
#       stroke="none"
#       fill="none"
#       fillRule="evenodd"
#       transform="translate(3.000000, 3.000000)"
#     >
#       <path
#         d="M9,12 C9.55228475,12 10,12.4477153 10,13 C10,13.5522847 9.55228475,14 9,14 C8.44771525,14 8,13.5522847 8,13 C8,12.4477153 8.44771525,12 9,12 Z"
#         className="icon_svg-fill_as_stroke"
#         fill="#666666"
#         fillRule="nonzero"
#       />
#       <path
#         d="M9,9.5 L9,4.5 L9,9.5 Z M9,18 C4.029,18 0,13.971 0,9 C0,4.029 4.029,0 9,0 C13.971,0 18,4.029 18,9 C18,13.971 13.971,18 9,18 Z"
#         className="icon_svg-stroke"
#         stroke="#666"
#         strokeWidth="1.5"
#         strokeLinecap="round"
#       />
#     </g>
#   </svg><p style='text-align: center; margin-top: 8px; max-width: 60vw;margin-bottom: 16px;'>Something went wrong. Wait a moment and try again.</p><button onclick='location.reload();' style='padding: 8px 16px;font-size: 15px; background-color: #2E69FF; color: #fff;border: 0; border-radius: 9999em; appearance: none;cursor:pointer;-webkit-appearance: none;font-family:-apple-system,system-ui,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen-Sans,Ubuntu,Cantarell,"Helvetica Neue",sans-serif;'>Try again</button></div></div><script type="text/javascript">window.addEventListener("load",function(e){window.errorTimer=window.setTimeout(function(){var e=document.getElementById("root");if(e&&e.children&&0===e.children.length&&!window.initialRenderComplete){var t=document.getElementById("loader");t&&t.remove();var n=document.getElementById("staticError");if(n&&n.style&&n.style.display){n.style.display="block";var o=new XMLHttpRequest;o.open("POST","/ajax/log_static_error_state_shown_3RD_PARTY_POST",!0),o.setRequestHeader("Content-Type","application/x-www-form-urlencoded; charset=UTF-8"),o.setRequestHeader("Accept","*/*"),o.send("")}}},1e4)});
# </script><div style='height: calc(100vh - 50px);margin-top: 50px;display: flex;font-size: 15px;background-color: #fff;flex-direction: column;align-items: center;justify-content: center;font-family: -apple-system,system-ui,BlinkMacSystemFont,"Segoe UI",Roboto,Oxygen-Sans,Ubuntu,Cantarell,"Helvetica Neue",sans-serif' id='loader' class=''><div style='position: fixed;top: 0;left: 0;right: 0;height: 50px;background-color: #fff;border-bottom: 1px solid rgb(222, 224, 225);box-shadow: 0 3px 6px rgba(0, 0, 0, 0.04)'></div><style>@keyframes loader-line{0%{transform:translateX(calc(-100% + 3px));opacity:.5}25%,75%{opacity:1}50%{transform:translateX(calc(100% - 3px));opacity:.5}100%{transform:translateX(calc(-100% + 3px));opacity:.5}}@keyframes entrance{0%{transform:scale(.9);opacity:0}100%{transform:scale(1);opacity:1}}@keyframes logo-entrance{100%{fill:#b92b27;opacity:1}}@keyframes logo-entrance-dark{100%{fill:#f52936;opacity:1}}#loader svg{width:48px;height:48px}#loader svg path{fill:#8e9092;opacity:.6;animation:logo-entrance .15s ease-in forwards;animation-delay:1s}#loader.loader-dark svg path{fill:#8e9092;animation-name:logo-entrance-dark}</style><svg width="24" height="24" viewBox="0 0 24 24" fill="none" xmlns="http://www.w3.org/2000/svg">
# <path class="icon_svg-fill_as_stroke" d="M20.7364 19.4633L18.9688 17.6952C20.2382 16.1439 21.0001 14.161 21.0001 12C21 7.02939 16.9705 3 12 3C7.02939 3 3 7.02939 3 12C3 16.9705 7.02948 20.9999 12 21C12.0114 21 12.0226 20.9996 12.0339 20.9996H20.0999C20.9016 20.9996 21.3032 20.0303 20.7364 19.4633ZM6.59998 12C6.59998 9.01765 9.01765 6.59998 12 6.59998C14.9823 6.59998 17.3999 9.01765 17.4 12C17.4 14.9823 14.9823 17.3999 12 17.3999C9.01765 17.4 6.59998 14.9823 6.59998 12Z" fill="#B92B27"/>
# </svg>
# <div style='height: 3px;width: 20px;position: relative;border-radius: 1000px;margin-top: 6px;overflow: hidden;animation: entrance .15s ease-in 1s 1 both'><div style='position: absolute;top: 0px;bottom: 0px;left: 0px;width: 100%;background-color: rgba(0, 0, 0, 0.2);border-radius: 1000px;animation: loader-line 1.5s cubic-bezier(0.83, 0, 0.17, 1) 1s infinite both;transform-origin: left center;opacity: 0'></div></div></div><script type="text/javascript">window.loaderTimer=setTimeout(function(){var e=document.getElementById("loader");e&&e.style&&e.style.display&&(e.style.display="flex")},100);
# </script><div id='root'></div><noscript>Please enable Javascript and refresh the page to continue</noscript><script type="text/javascript">window.ansFrontendGlobals = window.ansFrontendGlobals || {};window.ansFrontendGlobals.settings = {"action": "q", "controller": "question", "pageOid": 97315626, "getPageTypeOfRefererUrl": null, "getParams": {}, "cookiePrefix": "m", "nid": 0, "revision": "13d7438b7956c85ea963867381e477936986033a", "isCanaryRevision": false, "debugToolsEnabled": false, "postkey": "31c589a57ea1cd3e67fafa03f3f20164", "buildNumber": 0, "broadcastId": "main-w-chan50-8888-react_iunqkinyxqlspoya-WS91", "broadcastDisabled": false, "tchannelData": null, "viewerUniversalUid": null, "viewerMemberUid": null, "isMemberQuoraEmployee": false, "shouldReportE2E": true, "shouldReportReactLoadableE2E": true, "cdn": "cloudflare", "request_id": "aef4493639714fa08e11c3645791b87b", "actionTrail": null, "clientLogTrail": null, "experiments": {"test_experiment_name_2": null, "new_progressive_page_wrapper_logged_in": null, "new_progressive_page_wrapper_logged_out": null, "app_download_wall_holdout": null, "android_disable_branch_auto_login": null, "ios_disable_branch_auto_login": null, "remove_more_stories_from_digest_ad": null, "standard_ad_copy_logged_in": null, "standard_ad_copy_logged_out": null, "question_page_image_ads_v2_logged_in": null, "question_page_image_ads_v2_logged_out": null, "subscriptions_logged_in_holdout": null, "subscriptions_quora_plus_corner_badge_2": null, "share_answer_skip_redirect": null, "draft_image_generation": null, "feed_hide_image_generation_thumbnail": null, "show_more_images_on_qtext_truncated_logged_in": null, "show_more_images_on_qtext_truncated_logged_out": null, "show_outbound_link_modal": null, "show_outbound_link_modal_logged_out": null, "web_ui_refresh_logged_in": null, "web_ui_refresh_logged_out": null, "qp_ranking_llm_reranker_logged_in": null, "qp_ranking_llm_reranker_logged_out": null, "logged_out_home_feed_i18n": null, "question_page_llm_answer_less_prominent_logged_in": null, "question_page_llm_answer_less_prominent_logged_out": null, "logged_out_quora_to_poe_handover_go_to_login_page": "go_to_login_page"}, "features": {"SmartQuotesEnabled": true, "DisabledEditorCommands": [], "PreventActionBarOverflow": false, "StyleLineHeightFeature": 1, "StyleFontFamilyFeature": 1, "DefaultContentBidiDirectionIsRTL": false, "AllowColorModesInInterface": false, "UseAllCapsInInterface": true, "SpammerCaptchaChallengeCondition": false, "TribesNameCharacterLimit": 50, "TribesDescriptionCharacterLimit": 80, "TribesRulesCharacterLimit": 1600, "AdTransparencyReasonsAndOptions": false, "CommentAdsEnabled": true, "TribeEarningsProgramFeature": true, "PaidSubscriptionEnabledForProducer": true, "ConsumerDirectSubscriptions": true, "ConsumerBundleSubscriptions": true, "ShowPaywallsToConsumers": true, "EnableSubscriptionsDebugMode": false, "EnableContentDemonetizationUpdate": true, "IsEligibleForINPricing": true, "DisableBundlePricingTest": false, "LoggedOutHomeFeedEnabled": false, "QuestionPagedListAnswerGroupingUXEnabled": false, "ShowPrivacyChoicesLink": false, "ShowCookieWarning": false, "NuxFollowTopicsLowerRequirements": true, "UseExtraAnimationInInterface": true, "TimeSeriesStatsNumBins": 30}, "gates": {"poe_rebrand_multibot_assets": true, "quora_to_poe_handover_updated_deeplink_logic": true, "quora_plus_require_state_from_india": true, "enable_quora_plus_business_tax_id_collection": true, "privacy_sandbox_attribution_registration": true, "question_page_promoted_answer_attribution_location": "control", "keep_empty_programmatic_ad_slot_for_ad_blocker": false, "test_ad_id": null, "ads_show_message_banner": {"learn_more_link": "", "message": ""}, "ads_power_user_accounts": [527765581395999, 527765581347597, 527765581430418, 527765581357948, 527765581506382, 45, 527765581332623, 527765581381996, 527765581357948, 527765581336168, 527765581680251, 527765581357110, 527765581966634, 527765581922413, 527765581395999 ...
#                     window.executeAfterEntryjsLoaded(
#                         () => window.setTimingData({"server_time":794.994,"total_worker_time":6650.732,"window_id":"react_iunqkinyxqlspoya","page":794.994,"request":801.588}));
#
#                     window.executeAfterEntryjsLoaded(
#                         () => window.reportPageSpeedData({"standard":{}}));
#
#                 </script></body></html>

# %%
print(links[0:2])
# Out:
# ['https://www.quora.com/How-many-calories-does-Malai-Chaap-have', 'https://www.fatsecret.co.in/calories-nutrition/search?q=Malai+Chaap']

# %%
def calorie_data_scraper(food_name:str):
    url = "https://trackapi.nutritionix.com/v2/natural/nutrients"
    # url2 = "https://trackapi.nutritionix.com/v2/search/instant/?query=mcdonaldsalootikki"
    headers = {"Content-Type": "application/json",
              "x-app-id":"4031d7ed",
              "x-app-key":"77c515afe6b2c5fd3dfba64d0c005213"}
    body = {"query": "mcdonalds aloo tikki burger"}
    response = requests.post(url,json=body, headers=headers)
    # response = requests.get(url2, headers=headers)
    return str(response.json())
